# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt
import plotly.express as px

import calendar 
import plotly.graph_objects as go


import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'C:\Users\Islam\Desktop\projects bi\unployment india\archive_3\Unemployment_Rate_upto_11_2020.csv')

# %%
df.sample(10)
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 264    West Bengal   31-08-2020          M                             14.87
# 38    Chhattisgarh   30-09-2020          M                              1.96
# 177     Puducherry   30-09-2020          M                             10.90
# 240  Uttar Pradesh   30-04-2020          M                             21.54
# 74         Haryana   31-05-2020          M                             29.02
# 198      Rajasthan   31-10-2020          M                             24.15
# 21           Bihar   29-02-2020          M                             10.29
# 224      Telangana   31-08-2020          M                              5.79
# 37    Chhattisgarh   31-08-2020          M                              5.63
# 139    Maharashtra   31-01-2020          M                              4.95
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
df.columns = ['state','date',
              'frequency',
              'estimated unemployment rate',
              'estimated employed',
              'estimated labour participation rate',
              'region',
              'longitude',
              'latitude']
df.head()
# Out:
#             state         date frequency  estimated unemployment rate  \
# 0  Andhra Pradesh   31-01-2020         M                         5.48
# 1  Andhra Pradesh   29-02-2020         M                         5.83
# 2  Andhra Pradesh   31-03-2020         M                         5.79
# 3  Andhra Pradesh   30-04-2020         M                        20.51
# 4  Andhra Pradesh   31-05-2020         M                        17.43
#
#    estimated employed  estimated labour participation rate region  longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    latitude
# 0     79.74
# 1     79.74
# 2     79.74
# 3     79.74
# 4     79.74

# %%
df.isnull().sum()
# Out:
# state                                  0
# date                                   0
# frequency                              0
# estimated unemployment rate            0
# estimated employed                     0
# estimated labour participation rate    0
# region                                 0
# longitude                              0
# latitude                               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.state.value_counts()
# Out:
# state
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: count, dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(data =df,hue ='region')
plt.show()

# %%
df_heat = df[['estimated unemployment rate','estimated employed','estimated labour participation rate','longitude','latitude']].corr()

# %%
sns.heatmap(data=df_heat,annot=True)
plt.show()

# %%
df.region.value_counts()
# Out:
# region
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: count, dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   state                                267 non-null    object
#  1   date                                 267 non-null    datetime64[ns]
#  2   frequency                            267 non-null    object
#  3   estimated unemployment rate          267 non-null    float64
#  4   estimated employed                   267 non-null    int64
#  5   estimated labour participation rate  267 non-null    float64
#  6   region                               267 non-null    object
#  7   longitude                            267 non-null    float64
#  8   latitude                             267 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 18.9+ KB

# %%
df['month'] = df['date'].dt.month
df['Month_int'] = df['month'].apply(lambda x : int(x))
df['Month_int'] = df['month'].apply(lambda x : int(x))
df['Month_name'] =  df['Month_int'].apply(lambda x: calendar.month_abbr[x])
df.drop(columns='month',inplace=True)

df
# Out:
#               state       date frequency  estimated unemployment rate  \
# 0    Andhra Pradesh 2020-01-31         M                         5.48
# 1    Andhra Pradesh 2020-02-29         M                         5.83
# 2    Andhra Pradesh 2020-03-31         M                         5.79
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 4    Andhra Pradesh 2020-05-31         M                        17.43
# ..              ...        ...       ...                          ...
# 262     West Bengal 2020-06-30         M                         7.29
# 263     West Bengal 2020-07-31         M                         6.83
# 264     West Bengal 2020-08-31         M                        14.87
# 265     West Bengal 2020-09-30         M                         9.35
# 266     West Bengal 2020-10-31         M                         9.98
#
#      estimated employed  estimated labour participation rate region  \
# ...

# %%
df['region'] = df['region'].astype('category')
df.head()
# Out:
#             state       date frequency  estimated unemployment rate  \
# 0  Andhra Pradesh 2020-01-31         M                         5.48
# 1  Andhra Pradesh 2020-02-29         M                         5.83
# 2  Andhra Pradesh 2020-03-31         M                         5.79
# 3  Andhra Pradesh 2020-04-30         M                        20.51
# 4  Andhra Pradesh 2020-05-31         M                        17.43
#
#    estimated employed  estimated labour participation rate region  longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    latitude  Month_int Month_name
# 0     79.74          1        Jan
# ...

# %%
state = df.groupby(['state'])[['estimated unemployment rate' , 'estimated employed' , 'estimated labour participation rate']].mean().reset_index()
state
# Out:
#                state  estimated unemployment rate  estimated employed  \
# 0     Andhra Pradesh                     8.664000        1.542548e+07
# 1              Assam                     4.856000        1.081028e+07
# 2              Bihar                    19.471000        2.360683e+07
# 3       Chhattisgarh                     7.819000        8.421349e+06
# 4              Delhi                    18.414000        4.632822e+06
# 5                Goa                    12.167000        4.423748e+05
# 6            Gujarat                     6.376000        2.273075e+07
# 7            Haryana                    27.477000        6.844059e+06
# 8   Himachal Pradesh                    16.065000        2.033885e+06
# 9    Jammu & Kashmir                    16.477778        3.310032e+06
# 10         Jharkhand                    19.539000        8.770642e+06
# 11         Karnataka                     7.668000        2.162402e+07
# ...

# %%
region = df.groupby(['region'])[['estimated unemployment rate' , 'estimated employed' , 'estimated labour participation rate']].mean().reset_index()
region
# Out:
#       region  estimated unemployment rate  estimated employed  \
# 0       East                    13.916000        1.960237e+07
# 1      North                    15.889620        1.307249e+07
# 2  Northeast                    10.950263        3.617106e+06
# 3      South                    10.454667        1.404059e+07
# 4       West                     8.239000        1.862351e+07
#
#    estimated labour participation rate
# 0                            40.108750
# 1                            38.702658
# 2                            52.055263
# 3                            40.436167
# 4                            41.257000

# %%
fig = px.box(data_frame=df,x='state',y='estimated unemployment rate',color='state',title='Unemployment rate')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()

# %%
fig = px.bar(df,x='Month_name',y='estimated employed',color='Month_name',
            category_orders ={'month':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct']},
            title='Estimated employed people from Jan 2020 to Oct 2020')
fig.show()

# %%
fg = px.scatter(df,x='region',y='estimated unemployment rate',color='region')
fg.show()

# %%
fig = px.bar(state,x='state',y='estimated unemployment rate',color='state',title='Average unemployment rate (State)')
fig.show()

# %%
fig = px.bar(df,x='state',y='estimated unemployment rate',color='state',
            title='Unemployment rate from Jan 2020 to Oct by  2020State')
fig.show()

# %%
fig= px.scatter_matrix(df,dimensions=['estimated unemployment rate','estimated employed','estimated labour participation rate'],color='region')
fig.show()

# %%
fig = px.bar(region,x='region',
             y='estimated unemployment rate',
             color='region',
             title='Average unemployment rate(region)')
fig.show()

# %%
unemployment =df.groupby(['region','state'])['estimated unemployment rate'].mean().reset_index()

# %%
fig = px.sunburst(unemployment,path=['region','state'],values='estimated unemployment rate',
                 title ='Unemployment Rate in State and Region',height=1000)
fig.show()

# %%
after_lock = df[(df['Month_int'] >= 4) & (df['Month_int'] <=7)]
lock
# Out:
#               state       date frequency  estimated unemployment rate  \
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 4    Andhra Pradesh 2020-05-31         M                        17.43
# 5    Andhra Pradesh 2020-06-30         M                         3.31
# 6    Andhra Pradesh 2020-07-31         M                         8.34
# 13            Assam 2020-04-30         M                        11.06
# ..              ...        ...       ...                          ...
# 253     Uttarakhand 2020-07-31         M                        12.38
# 260     West Bengal 2020-04-30         M                        17.41
# 261     West Bengal 2020-05-31         M                        17.41
# 262     West Bengal 2020-06-30         M                         7.29
# 263     West Bengal 2020-07-31         M                         6.83
#
#      estimated employed  estimated labour participation rate     region  \
# ...

# %%
beforelock = df[(df['Month_int'] >= 1) & (df['Month_int'] <=4)]
beforelock
# Out:
#               state       date frequency  estimated unemployment rate  \
# 0    Andhra Pradesh 2020-01-31         M                         5.48
# 1    Andhra Pradesh 2020-02-29         M                         5.83
# 2    Andhra Pradesh 2020-03-31         M                         5.79
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 10            Assam 2020-01-31         M                         4.66
# ..              ...        ...       ...                          ...
# 250     Uttarakhand 2020-04-30         M                         6.48
# 257     West Bengal 2020-01-31         M                         6.94
# 258     West Bengal 2020-02-29         M                         4.92
# 259     West Bengal 2020-03-31         M                         6.92
# 260     West Bengal 2020-04-30         M                        17.41
#
#      estimated employed  estimated labour participation rate     region  \
# ...

# %%
fig = px.histogram(df,x='region',y='estimated unemployment rate',color='region',title='unemployment rate',animation_frame='date',template='plotly')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()

# %%
df = pd.DataFrame(df)
df.to_csv('final.csv',index=False)
